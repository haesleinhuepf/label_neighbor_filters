# %%
import numpy as np
from skimage.io import imread
import pyclesperanto_prototype as cle
import oclrfc
import napari
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

cle.select_device("RTX")
# Out:
# <NVIDIA GeForce RTX 3050 Ti Laptop GPU on Platform: NVIDIA CUDA (2 refs)>

# %% [markdown]
# The example data is available from https://git.mpi-cbg.de/rhaase/clij2_example_data

# %%
tribolium = cle.push(imread("../../data/clij2_example_data/lund1051_resampled.tif"))
cle.imshow(tribolium)

# %%
cells = cle.push(imread("../../data/clij2_example_data/lund1051_labelled.tif"))
cle.imshow(cells, labels=True)

# %%
annotation = cle.push(imread("tribolium_annotation.tif"))
cle.imshow(annotation, labels=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4680/1552843347.py in <module>
# ----> 1 annotation = cle.push(imread("tribolium_annotation.tif"))
#       2 cle.imshow(annotation, labels=True)
#
# ~\miniconda3\envs\bio1\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# ~\miniconda3\envs\bio1\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# ~\miniconda3\envs\bio1\lib\site-packages\skimage\io\_plugins\tifffile_plugin.py in imread(fname, **kwargs)
#      28         kwargs['key'] = kwargs.pop('img_num')
#      29
# ---> 30     return tifffile_imread(fname, **kwargs)
#
# ~\miniconda3\envs\bio1\lib\site-packages\tifffile\tifffile.py in imread(files, aszarr, **kwargs)
#     814
#     815         if isinstance(files, (str, os.PathLike)) or hasattr(files, 'seek'):
# --> 816             with TiffFile(files, **kwargs_file) as tif:
#     817                 if aszarr:
#     818                     return tif.aszarr(**kwargs)
#
# ~\miniconda3\envs\bio1\lib\site-packages\tifffile\tifffile.py in __init__(self, arg, mode, name, offset, size, _multifile, _useframes, _master, **kwargs)
#    2998             raise ValueError(f'invalid mode {mode!r}')
#    2999
# -> 3000         fh = FileHandle(arg, mode=mode, name=name, offset=offset, size=size)
#    3001         self._fh = fh
#    3002         self._multifile = bool(_multifile)
#
# ~\miniconda3\envs\bio1\lib\site-packages\tifffile\tifffile.py in __init__(self, file, mode, name, offset, size)
#    9535         self.is_file = None
#    9536         self._lock = NullContext()
# -> 9537         self.open()
#    9538
#    9539     def open(self):
#
# ~\miniconda3\envs\bio1\lib\site-packages\tifffile\tifffile.py in open(self)
#    9548             self._file = os.path.realpath(self._file)
#    9549             self._dir, self._name = os.path.split(self._file)
# -> 9550             self._fh = open(self._file, self._mode)
#    9551             self._close = True
#    9552             if self._offset is None:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\structure\\code\\label_neighbor_filters\\tribolium_annotation.tif'

# %% [markdown]
# The classifier was trained interactively using [napari-oclrfc](https://github.com/haesleinhuepf/napari-oclrfc).

# %%
classifier = oclrfc.OCLRandomForestLabelClassifier("triple_label_classifier.cl")

cell_classification = classifier.predict(cells, tribolium)

cle.imshow(cell_classification, color_map='turbo')

# %%
corrected_classification = cle.mode_of_proximal_neighbors_map(cell_classification, cells, max_distance=50)

cle.imshow(corrected_classification, color_map='turbo')

# %%
fig, axs = plt.subplots(1, 4, figsize=(15,7))

cle.imshow(tribolium, plot=axs[0])
axs[0].set_title('Original image (resampled)')
cle.imshow(cells, labels=True, plot=axs[1])
axs[1].set_title('Cells label image')
cle.imshow(cell_classification, plot=axs[2])
axs[2].set_title('Noisy cell classification')
cle.imshow(corrected_classification, plot=axs[3])
axs[3].set_title('Corrected cell classification')
# Out:
# Text(0.5, 1.0, 'Corrected cell classification')

# %%
fig.savefig("tribolium_mode_cell_classification.png", dpi=400, bbox_inches = 'tight', pad_inches=0.1)
